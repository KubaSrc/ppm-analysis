# %%
from src.PPM import ppm

PPM = ppm.mechanism(A=25.15,B=38,C=76,D=58.25)
PPM.draw()
# Out:
# [0 0 0] [25.15  0.    0.  ] [50.3  0.   0. ]
# [array([0, 0, 0]), array([25.15,  0.  ,  0.  ]), array([50.3,  0. ,  0. ])]
